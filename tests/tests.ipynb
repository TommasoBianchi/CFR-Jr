# %%
from functools import reduce
import notebook_importer
from trees import Tree, Node, Leaf, randomTree
from cfr import CFRTree, SolveWithSampleCFR
import random
import math
import re
import time
# Out:
# importing Jupyter notebook from trees.ipynb
# importing Jupyter notebook from cfr.ipynb

# %%
def randomTreeTest(depth = 2, branching_factor = 2, players = 2, p = 1, iterations = 1000, debug = False):
    bt = randomTree(depth, branching_factor, p, players)
    t = CFRTree(bt)
    res = SolveWithSampleCFR(t, players, iterations)
    epsilon = t.checkEquilibrium(res['joint'])
    
    if(debug):
        print("Random tree test:")
        print("Utility = " + str(res['utility']))
        print("Epsilon = " + str(epsilon))
        print("")
    
    return {'utility': res['utility'], 'epsilon': epsilon, 'tree': t, 'joint': res['joint'], 'base_tree': bt}

# %%
import time

interesting_results = []

N = 2
iterations = 50
epsilon_limit = 5

def checkCFR(settings):
    (num_players, depth, branching_factor, infoset_probability) = settings    
    max_eps = 0
    start = time.time()
    
    print("----------------------------------------------------------------------------------------")
    print("{} players, depth {}, branching factor {}, infoset probability {}".format(\
         num_players, depth, branching_factor, infoset_probability))
        
    for i in range(N+1):
        #if(i % (N / 10) == 0):
        #    print(i)
        r = randomTreeTest(depth = depth, branching_factor = branching_factor,\
                           p = infoset_probability, players = num_players, iterations = iterations)
        mod_eps = math.sqrt(reduce(lambda acc, el: acc + el * el, 
                                   filter(lambda el: el < 0, r['epsilon']), 0))
        max_eps = max(max_eps, mod_eps)
        if(mod_eps > epsilon_limit):
            interesting_results.append(r)
    
    print("Found " + str(len(interesting_results)) + " interesting results")
    print("Maximum |epsilon| (without counting positive epsilon elements) = " + str(max_eps))
    print(str(N) + " trees for " + str(iterations) + " iterations in " + str(time.time() - start) + " seconds")
    print("----------------------------------------------------------------------------------------")

players = [2, 3, 4]
depths = [2, 4, 6, 8]
branching_factors = [2]
infoset_probabilities = [0, 1]

for p in players:
    for d in depths:
        for bf in branching_factors:
            for ip in infoset_probabilities:
                checkCFR((p, d, bf, ip))
    
interesting_results
# Out:
# ----------------------------------------------------------------------------------------
# 2 players, depth 2, branching factor 2, infoset probability 0
# Found 0 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 3.7643060449437407
# 2 trees for 50 iterations in 0.008600711822509766 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 2, branching factor 2, infoset probability 1
# Found 0 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.3671868928570075
# 2 trees for 50 iterations in 0.011626005172729492 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 4, branching factor 2, infoset probability 0
# Found 0 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 4.420407221060071
# 2 trees for 50 iterations in 0.03562498092651367 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 4, branching factor 2, infoset probability 1
# Found 0 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 3.632079294288618
# 2 trees for 50 iterations in 0.03260350227355957 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 6, branching factor 2, infoset probability 0
# Found 2 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 12.429448901701164
# 2 trees for 50 iterations in 0.09059333801269531 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 6, branching factor 2, infoset probability 1
# Found 4 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 9.440000000000012
# 2 trees for 50 iterations in 0.14702773094177246 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 8, branching factor 2, infoset probability 0
# Found 7 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 19.133990697185972
# 2 trees for 50 iterations in 0.43468379974365234 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 2 players, depth 8, branching factor 2, infoset probability 1
# Found 10 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 20.979999999999983
# 2 trees for 50 iterations in 0.8545520305633545 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 2, branching factor 2, infoset probability 0
# Found 10 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.1872657663724666
# 2 trees for 50 iterations in 0.008626937866210938 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 2, branching factor 2, infoset probability 1
# Found 10 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.3199999999999932
# 2 trees for 50 iterations in 0.008550882339477539 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 4, branching factor 2, infoset probability 0
# Found 10 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 3.8849967824954463
# 2 trees for 50 iterations in 0.03434276580810547 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 4, branching factor 2, infoset probability 1
# Found 11 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 5.739999999999995
# 2 trees for 50 iterations in 0.03953289985656738 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 6, branching factor 2, infoset probability 0
# Found 13 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 10.00000000000003
# 2 trees for 50 iterations in 0.1390073299407959 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 6, branching factor 2, infoset probability 1
# Found 14 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 5.140000000000015
# 2 trees for 50 iterations in 0.20374774932861328 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 8, branching factor 2, infoset probability 0
# Found 17 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 16.416637901836047
# 2 trees for 50 iterations in 0.5827863216400146 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 3 players, depth 8, branching factor 2, infoset probability 1
# Found 20 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 14.400000000000006
# 2 trees for 50 iterations in 0.9511830806732178 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 2, branching factor 2, infoset probability 0
# Found 20 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.6972919607421701
# 2 trees for 50 iterations in 0.010413169860839844 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 2, branching factor 2, infoset probability 1
# Found 20 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.5861904047118744
# 2 trees for 50 iterations in 0.010054826736450195 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 4, branching factor 2, infoset probability 0
# Found 20 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 1.4340153416194594
# 2 trees for 50 iterations in 0.04451775550842285 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 4, branching factor 2, infoset probability 1
# Found 20 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 2.1599999999999966
# 2 trees for 50 iterations in 0.052306413650512695 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 6, branching factor 2, infoset probability 0
# Found 22 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 8.83999999999999
# 2 trees for 50 iterations in 0.19911479949951172 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 6, branching factor 2, infoset probability 1
# Found 23 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 9.819999999999993
# 2 trees for 50 iterations in 0.23133373260498047 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 8, branching factor 2, infoset probability 0
# Found 26 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 15.964523168576006
# 2 trees for 50 iterations in 0.8703451156616211 seconds
# ----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------
# 4 players, depth 8, branching factor 2, infoset probability 1
# Found 29 interesting results
# Maximum |epsilon| (without counting positive epsilon elements) = 9.259999999999991
# 2 trees for 50 iterations in 1.2228529453277588 seconds
# ----------------------------------------------------------------------------------------
# [{'base_tree': <trees.Tree at 0x7f62965fa320>,
#   'epsilon': [-4.6000000000000085, -4.480000000000018],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296608dd8>,
#   'tree': <cfr.CFRTree at 0x7f6296608da0>,
#   'utility': [72, 91]},
#  {'base_tree': <trees.Tree at 0x7f6296627748>,
#   'epsilon': [-7.160000000000004, -10.16000000000001],
#   'joint': <cfr.CFRJointStrategy at 0x7f62966186a0>,
#   'tree': <cfr.CFRTree at 0x7f6296627828>,
#   'utility': [98, 85]},
#  {'base_tree': <trees.Tree at 0x7f6296627668>,
#   'epsilon': [23.28, -9.039999999999992],
#   'joint': <cfr.CFRJointStrategy at 0x7f629658cd30>,
#   'tree': <cfr.CFRTree at 0x7f62966187b8>,
#   'utility': [93, 83]},
#  {'base_tree': <trees.Tree at 0x7f629658cda0>,
#   'epsilon': [26.11999999999999, -9.440000000000012],
#   'joint': <cfr.CFRJointStrategy at 0x7f62965a8470>,
#   'tree': <cfr.CFRTree at 0x7f629658cdd8>,
#   'utility': [99, 99]},
#  {'base_tree': <trees.Tree at 0x7f62965a84e0>,
#   'epsilon': [-11.699999999999989, -15.139999999999986],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296626a58>,
#   'tree': <cfr.CFRTree at 0x7f62965a8978>,
#   'utility': [28, 99]},
#  {'base_tree': <trees.Tree at 0x7f6296626b00>,
#   'epsilon': [-6.720000000000027, -16.560000000000002],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296517b70>,
#   'tree': <cfr.CFRTree at 0x7f6296626ac8>,
#   'utility': [91, 98]},
#  {'base_tree': <trees.Tree at 0x7f6296517c50>,
#   'epsilon': [-9.90000000000002, -12.599999999999966],
#   'joint': <cfr.CFRJointStrategy at 0x7f62964e0ba8>,
#   'tree': <cfr.CFRTree at 0x7f6296517be0>,
#   'utility': [89, 80]},
#  {'base_tree': <trees.Tree at 0x7f62964e0c50>,
#   'epsilon': [-1.8800000000000097, -10.659999999999982],
#   'joint': <cfr.CFRJointStrategy at 0x7f62964bb828>,
#   'tree': <cfr.CFRTree at 0x7f62964e0c18>,
#   'utility': [87, 92]},
#  {'base_tree': <trees.Tree at 0x7f62964bb898>,
#   'epsilon': [-20.979999999999983, 3.7600000000000193],
#   'joint': <cfr.CFRJointStrategy at 0x7f62964194a8>,
#   'tree': <cfr.CFRTree at 0x7f62964bb8d0>,
#   'utility': [97, 40]},
#  {'base_tree': <trees.Tree at 0x7f62964195f8>,
#   'epsilon': [-9.379999999999995, 10.259999999999977],
#   'joint': <cfr.CFRJointStrategy at 0x7f62963f7128>,
#   'tree': <cfr.CFRTree at 0x7f6296419eb8>,
#   'utility': [85, 100]},
#  {'base_tree': <trees.Tree at 0x7f6296386898>,
#   'epsilon': [15.760000000000012, -5.739999999999995, 3.960000000000008],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296394940>,
#   'tree': <cfr.CFRTree at 0x7f6296382240>,
#   'utility': [75, 100, 74]},
#  {'base_tree': <trees.Tree at 0x7f629638e828>,
#   'epsilon': [-4.860000000000035, 1.680000000000021, -2.8799999999999812],
#   'joint': <cfr.CFRJointStrategy at 0x7f62963a4908>,
#   'tree': <cfr.CFRTree at 0x7f6296394a58>,
#   'utility': [84, 76, 94]},
#  {'base_tree': <trees.Tree at 0x7f62963a4ac8>,
#   'epsilon': [-3.5200000000000102, -9.360000000000028, 2.940000000000012],
#   'joint': <cfr.CFRJointStrategy at 0x7f62963b8940>,
#   'tree': <cfr.CFRTree at 0x7f62963a4a20>,
#   'utility': [100, 87, 95]},
#  {'base_tree': <trees.Tree at 0x7f62b4e38710>,
#   'epsilon': [-5.140000000000015, 2.6200000000000045, 6.339999999999975],
#   'joint': <cfr.CFRJointStrategy at 0x7f62963787b8>,
#   'tree': <cfr.CFRTree at 0x7f6296366518>,
#   'utility': [80, 74, 73]},
#  {'base_tree': <trees.Tree at 0x7f62963b89b0>,
#   'epsilon': [-12.380000000000024, 24.899999999999963, -9.200000000000003],
#   'joint': <cfr.CFRJointStrategy at 0x7f629631f5f8>,
#   'tree': <cfr.CFRTree at 0x7f629638eef0>,
#   'utility': [98, 89, 100]},
#  {'base_tree': <trees.Tree at 0x7f629631f6a0>,
#   'epsilon': [-11.16000000000001, -8.700000000000003, 8.480000000000032],
#   'joint': <cfr.CFRJointStrategy at 0x7f62962e9630>,
#   'tree': <cfr.CFRTree at 0x7f629631f630>,
#   'utility': [100, 89, 94]},
#  {'base_tree': <trees.Tree at 0x7f62962e96d8>,
#   'epsilon': [-14.52000000000001, -7.659999999999975, 13.279999999999994],
#   'joint': <cfr.CFRJointStrategy at 0x7f62962b4668>,
#   'tree': <cfr.CFRTree at 0x7f62962e9668>,
#   'utility': [98, 37, 25]},
#  {'base_tree': <trees.Tree at 0x7f62962b4710>,
#   'epsilon': [21.960000000000004, -14.400000000000006, 4.459999999999994],
#   'joint': <cfr.CFRJointStrategy at 0x7f62962112e8>,
#   'tree': <cfr.CFRTree at 0x7f62962b46a0>,
#   'utility': [25, 38, 97]},
#  {'base_tree': <trees.Tree at 0x7f6296211320>,
#   'epsilon': [-4.339999999999989, -5.620000000000019, 11.620000000000005],
#   'joint': <cfr.CFRJointStrategy at 0x7f62961e7f28>,
#   'tree': <cfr.CFRTree at 0x7f6296211390>,
#   'utility': [75, 98, 25]},
#  {'base_tree': <trees.Tree at 0x7f62961e7f60>,
#   'epsilon': [-11.360000000000035, 4.70000000000001, 11.64],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296148ba8>,
#   'tree': <cfr.CFRTree at 0x7f62961e7fd0>,
#   'utility': [81, 67, 87]},
#  {'base_tree': <trees.Tree at 0x7f6296166c88>,
#   'epsilon': [-5.1200000000000045,
#    6.159999999999997,
#    4.699999999999996,
#    -6.800000000000004],
#   'joint': <cfr.CFRJointStrategy at 0x7f629616ccf8>,
#   'tree': <cfr.CFRTree at 0x7f6296166da0>,
#   'utility': [94, 34, 56, 59]},
#  {'base_tree': <trees.Tree at 0x7f6296102d68>,
#   'epsilon': [-8.83999999999999,
#    29.35999999999997,
#    31.84000000000001,
#    6.6599999999999895],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296114dd8>,
#   'tree': <cfr.CFRTree at 0x7f6296102e48>,
#   'utility': [73, 54, 95, 90]},
#  {'base_tree': <trees.Tree at 0x7f629615aa90>,
#   'epsilon': [-9.819999999999993,
#    21.919999999999995,
#    16.199999999999967,
#    28.020000000000035],
#   'joint': <cfr.CFRJointStrategy at 0x7f629612aa58>,
#   'tree': <cfr.CFRTree at 0x7f629615af98>,
#   'utility': [89, 89, 98, 44]},
#  {'base_tree': <trees.Tree at 0x7f629616cda0>,
#   'epsilon': [-0.8599999999999994,
#    3.260000000000005,
#    22.599999999999994,
#    -7.720000000000006],
#   'joint': <cfr.CFRJointStrategy at 0x7f629608d160>,
#   'tree': <cfr.CFRTree at 0x7f62960c5630>,
#   'utility': [32, 62, 31, 87]},
#  {'base_tree': <trees.Tree at 0x7f62960c57b8>,
#   'epsilon': [9.36,
#    16.72000000000002,
#    -9.879999999999995,
#    -12.540000000000006],
#   'joint': <cfr.CFRJointStrategy at 0x7f62960adfd0>,
#   'tree': <cfr.CFRTree at 0x7f629608d240>,
#   'utility': [67, 80, 59, 59]},
#  {'base_tree': <trees.Tree at 0x7f62960b50f0>,
#   'epsilon': [-13.320000000000014,
#    10.859999999999992,
#    19.199999999999996,
#    -6.299999999999997],
#   'joint': <cfr.CFRJointStrategy at 0x7f6296000048>,
#   'tree': <cfr.CFRTree at 0x7f62960b52e8>,
#   'utility': [24, 99, 54, 44]},
#  {'base_tree': <trees.Tree at 0x7f62960000b8>,
#   'epsilon': [29.560000000000024,
#    29.000000000000014,
#    31.620000000000005,
#    -8.800000000000004],
#   'joint': <cfr.CFRJointStrategy at 0x7f6295fd4c88>,
#   'tree': <cfr.CFRTree at 0x7f6296000080>,
#   'utility': [98, 44, 73, 44]},
#  {'base_tree': <trees.Tree at 0x7f6295fd4cf8>,
#   'epsilon': [26.879999999999995,
#    36.660000000000004,
#    -9.259999999999991,
#    13.020000000000017],
#   'joint': <cfr.CFRJointStrategy at 0x7f62ad026438>,
#   'tree': <cfr.CFRTree at 0x7f6295fd4dd8>,
#   'utility': [20, 100, 4, 6]},
#  {'base_tree': <trees.Tree at 0x7f62ac471b00>,
#   'epsilon': [18.020000000000003,
#    32.43999999999997,
#    -6.060000000000031,
#    10.760000000000026],
#   'joint': <cfr.CFRJointStrategy at 0x7f6295f67c88>,
#   'tree': <cfr.CFRTree at 0x7f62ad08ef60>,
#   'utility': [98, 22, 80, 55]}]

# %%
id = 0
t = interesting_results[id]['tree']
bt = interesting_results[id]['base_tree']
joint = interesting_results[id]['joint']
bt.display()
# Out:
# Player 1 - Infoset 0 - Node 0
# Player 0 - Infoset 1 - Node 1 (children of Node0 via Action 0.0)
# Player 0 - Infoset 1 - Node 2 (children of Node0 via Action 0.1)
# Player 1 - Infoset 2 - Node 3 (children of Node1 via Action 1.0)
# Player 1 - Infoset 2 - Node 4 (children of Node1 via Action 1.1)
# Player 0 - Infoset 4 - Node 7 (children of Node3 via Action 2.0)
# Player 0 - Infoset 4 - Node 8 (children of Node3 via Action 2.1)
# Player 1 - Infoset 8 - Node 15 (children of Node7 via Action 4.0)
# Player 1 - Infoset 8 - Node 16 (children of Node7 via Action 4.1)
# Player 0 - Infoset 16 - Node 31 (children of Node15 via Action 8.0)
# Player 0 - Infoset 16 - Node 32 (children of Node15 via Action 8.1)
# Leaf63 (children of Node31 via Action 16.0) -  utility is [29, 81]
# Leaf64 (children of Node31 via Action 16.1) -  utility is [75, 65]
# Leaf65 (children of Node32 via Action 16.0) -  utility is [84, 78]
# Leaf66 (children of Node32 via Action 16.1) -  utility is [1, 14]
# Player 0 - Infoset 17 - Node 33 (children of Node16 via Action 8.0)
# Player 0 - Infoset 17 - Node 34 (children of Node16 via Action 8.1)
# Leaf67 (children of Node33 via Action 17.0) -  utility is [60, 45]
# Leaf68 (children of Node33 via Action 17.1) -  utility is [42, 48]
# Leaf69 (children of Node34 via Action 17.0) -  utility is [96, 35]
# Leaf70 (children of Node34 via Action 17.1) -  utility is [68, 9]
# Player 1 - Infoset 9 - Node 17 (children of Node8 via Action 4.0)
# Player 1 - Infoset 9 - Node 18 (children of Node8 via Action 4.1)
# Player 0 - Infoset 18 - Node 35 (children of Node17 via Action 9.0)
# Player 0 - Infoset 18 - Node 36 (children of Node17 via Action 9.1)
# Leaf71 (children of Node35 via Action 18.0) -  utility is [14, 8]
# Leaf72 (children of Node35 via Action 18.1) -  utility is [82, 9]
# Leaf73 (children of Node36 via Action 18.0) -  utility is [63, 39]
# Leaf74 (children of Node36 via Action 18.1) -  utility is [50, 22]
# Player 0 - Infoset 19 - Node 37 (children of Node18 via Action 9.0)
# Player 0 - Infoset 19 - Node 38 (children of Node18 via Action 9.1)
# Leaf75 (children of Node37 via Action 19.0) -  utility is [46, 69]
# Leaf76 (children of Node37 via Action 19.1) -  utility is [78, 89]
# Leaf77 (children of Node38 via Action 19.0) -  utility is [40, 2]
# Leaf78 (children of Node38 via Action 19.1) -  utility is [72, 91]
# Player 0 - Infoset 5 - Node 9 (children of Node4 via Action 2.0)
# Player 0 - Infoset 5 - Node 10 (children of Node4 via Action 2.1)
# Player 1 - Infoset 10 - Node 19 (children of Node9 via Action 5.0)
# Player 1 - Infoset 10 - Node 20 (children of Node9 via Action 5.1)
# Player 0 - Infoset 20 - Node 39 (children of Node19 via Action 10.0)
# Player 0 - Infoset 20 - Node 40 (children of Node19 via Action 10.1)
# Leaf79 (children of Node39 via Action 20.0) -  utility is [25, 54]
# Leaf80 (children of Node39 via Action 20.1) -  utility is [100, 41]
# Leaf81 (children of Node40 via Action 20.0) -  utility is [31, 27]
# Leaf82 (children of Node40 via Action 20.1) -  utility is [66, 36]
# Player 0 - Infoset 21 - Node 41 (children of Node20 via Action 10.0)
# Player 0 - Infoset 21 - Node 42 (children of Node20 via Action 10.1)
# Leaf83 (children of Node41 via Action 21.0) -  utility is [46, 14]
# Leaf84 (children of Node41 via Action 21.1) -  utility is [61, 4]
# Leaf85 (children of Node42 via Action 21.0) -  utility is [71, 15]
# Leaf86 (children of Node42 via Action 21.1) -  utility is [72, 31]
# Player 1 - Infoset 11 - Node 21 (children of Node10 via Action 5.0)
# Player 1 - Infoset 11 - Node 22 (children of Node10 via Action 5.1)
# Player 0 - Infoset 22 - Node 43 (children of Node21 via Action 11.0)
# Player 0 - Infoset 22 - Node 44 (children of Node21 via Action 11.1)
# Leaf87 (children of Node43 via Action 22.0) -  utility is [5, 92]
# Leaf88 (children of Node43 via Action 22.1) -  utility is [83, 78]
# Leaf89 (children of Node44 via Action 22.0) -  utility is [71, 69]
# Leaf90 (children of Node44 via Action 22.1) -  utility is [59, 10]
# Player 0 - Infoset 23 - Node 45 (children of Node22 via Action 11.0)
# Player 0 - Infoset 23 - Node 46 (children of Node22 via Action 11.1)
# Leaf91 (children of Node45 via Action 23.0) -  utility is [38, 48]
# Leaf92 (children of Node45 via Action 23.1) -  utility is [15, 1]
# Leaf93 (children of Node46 via Action 23.0) -  utility is [73, 78]
# Leaf94 (children of Node46 via Action 23.1) -  utility is [51, 65]
# Player 1 - Infoset 3 - Node 5 (children of Node2 via Action 1.0)
# Player 1 - Infoset 3 - Node 6 (children of Node2 via Action 1.1)
# Player 0 - Infoset 6 - Node 11 (children of Node5 via Action 3.0)
# Player 0 - Infoset 6 - Node 12 (children of Node5 via Action 3.1)
# Player 1 - Infoset 12 - Node 23 (children of Node11 via Action 6.0)
# Player 1 - Infoset 12 - Node 24 (children of Node11 via Action 6.1)
# Player 0 - Infoset 24 - Node 47 (children of Node23 via Action 12.0)
# Player 0 - Infoset 24 - Node 48 (children of Node23 via Action 12.1)
# Leaf95 (children of Node47 via Action 24.0) -  utility is [48, 40]
# Leaf96 (children of Node47 via Action 24.1) -  utility is [96, 51]
# Leaf97 (children of Node48 via Action 24.0) -  utility is [8, 36]
# Leaf98 (children of Node48 via Action 24.1) -  utility is [97, 9]
# Player 0 - Infoset 25 - Node 49 (children of Node24 via Action 12.0)
# Player 0 - Infoset 25 - Node 50 (children of Node24 via Action 12.1)
# Leaf99 (children of Node49 via Action 25.0) -  utility is [76, 58]
# Leaf100 (children of Node49 via Action 25.1) -  utility is [31, 73]
# Leaf101 (children of Node50 via Action 25.0) -  utility is [68, 60]
# Leaf102 (children of Node50 via Action 25.1) -  utility is [60, 90]
# Player 1 - Infoset 13 - Node 25 (children of Node12 via Action 6.0)
# Player 1 - Infoset 13 - Node 26 (children of Node12 via Action 6.1)
# Player 0 - Infoset 26 - Node 51 (children of Node25 via Action 13.0)
# Player 0 - Infoset 26 - Node 52 (children of Node25 via Action 13.1)
# Leaf103 (children of Node51 via Action 26.0) -  utility is [71, 77]
# Leaf104 (children of Node51 via Action 26.1) -  utility is [59, 87]
# Leaf105 (children of Node52 via Action 26.0) -  utility is [29, 99]
# Leaf106 (children of Node52 via Action 26.1) -  utility is [55, 69]
# Player 0 - Infoset 27 - Node 53 (children of Node26 via Action 13.0)
# Player 0 - Infoset 27 - Node 54 (children of Node26 via Action 13.1)
# Leaf107 (children of Node53 via Action 27.0) -  utility is [12, 40]
# Leaf108 (children of Node53 via Action 27.1) -  utility is [84, 90]
# Leaf109 (children of Node54 via Action 27.0) -  utility is [14, 90]
# Leaf110 (children of Node54 via Action 27.1) -  utility is [43, 3]
# Player 0 - Infoset 7 - Node 13 (children of Node6 via Action 3.0)
# Player 0 - Infoset 7 - Node 14 (children of Node6 via Action 3.1)
# Player 1 - Infoset 14 - Node 27 (children of Node13 via Action 7.0)
# Player 1 - Infoset 14 - Node 28 (children of Node13 via Action 7.1)
# Player 0 - Infoset 28 - Node 55 (children of Node27 via Action 14.0)
# Player 0 - Infoset 28 - Node 56 (children of Node27 via Action 14.1)
# Leaf111 (children of Node55 via Action 28.0) -  utility is [9, 85]
# Leaf112 (children of Node55 via Action 28.1) -  utility is [45, 57]
# Leaf113 (children of Node56 via Action 28.0) -  utility is [32, 16]
# Leaf114 (children of Node56 via Action 28.1) -  utility is [89, 38]
# Player 0 - Infoset 29 - Node 57 (children of Node28 via Action 14.0)
# Player 0 - Infoset 29 - Node 58 (children of Node28 via Action 14.1)
# Leaf115 (children of Node57 via Action 29.0) -  utility is [25, 10]
# Leaf116 (children of Node57 via Action 29.1) -  utility is [79, 77]
# Leaf117 (children of Node58 via Action 29.0) -  utility is [3, 88]
# Leaf118 (children of Node58 via Action 29.1) -  utility is [6, 89]
# Player 1 - Infoset 15 - Node 29 (children of Node14 via Action 7.0)
# Player 1 - Infoset 15 - Node 30 (children of Node14 via Action 7.1)
# Player 0 - Infoset 30 - Node 59 (children of Node29 via Action 15.0)
# Player 0 - Infoset 30 - Node 60 (children of Node29 via Action 15.1)
# Leaf119 (children of Node59 via Action 30.0) -  utility is [9, 2]
# Leaf120 (children of Node59 via Action 30.1) -  utility is [47, 41]
# Leaf121 (children of Node60 via Action 30.0) -  utility is [84, 30]
# Leaf122 (children of Node60 via Action 30.1) -  utility is [28, 48]
# Player 0 - Infoset 31 - Node 61 (children of Node30 via Action 15.0)
# Player 0 - Infoset 31 - Node 62 (children of Node30 via Action 15.1)
# Leaf123 (children of Node61 via Action 31.0) -  utility is [77, 43]
# Leaf124 (children of Node61 via Action 31.1) -  utility is [4, 21]
# Leaf125 (children of Node62 via Action 31.0) -  utility is [32, 71]
# Leaf126 (children of Node62 via Action 31.1) -  utility is [22, 33]

# %%
for plan in joint.plans:
    if(joint.plans[plan] / joint.frequencyCount > 0.01):
        print(plan, joint.plans[plan] / joint.frequencyCount)
        action_plan = CFRJointStrategy.stringToActionPlan(plan)
# Out:
# a0.1a1.0a3.0a4.0a6.0a12.0a14.0a16.0a18.1a24.1a25.0a26.0a28.1a29.1 0.02
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9e8f20a2be4c> in <module>()
#       2     if(joint.plans[plan] / joint.frequencyCount > 0.01):
#       3         print(plan, joint.plans[plan] / joint.frequencyCount)
# ----> 4         action_plan = CFRJointStrategy.stringToActionPlan(plan)
#
# NameError: name 'CFRJointStrategy' is not defined

# %% [markdown]
# # Test with classic (normal-form) regret matching

# %%
player1_regret = [0, 0]
player2_regret = [0, 0]

utilities = [[(95, 30), (49, 62)], [(22, 69), (76, 16)]]

joint2 = CFRJointStrategy(10)

# %%
for _ in range(10000):
    player1_regret_sum = max(player1_regret[0], 0) + max(player1_regret[1], 0)
    if(player1_regret_sum <= 0):
        player1_strategy = [0.5, 0.5]
    else:
        player1_strategy = [r / player1_regret_sum for r in player1_regret]
        
    player2_regret_sum = max(player2_regret[0], 0) + max(player2_regret[1], 0)
    if(player2_regret_sum <= 0):
        player2_strategy = [0.5, 0.5]
    else:
        player2_strategy = [r / player2_regret_sum for r in player2_regret]
        
    player1_action = 0 if(random.random() < player1_strategy[0]) else 1
    player2_action = 0 if(random.random() < player2_strategy[0]) else 1
    
    joint2.addActionPlan({0: player1_action, 1: player2_action})
    
    utility = utilities[player1_action][player2_action]
    
    ################################################################################
    ########### Regret matching + seems not to be working
    #player1_regret[0] += max(utilities[0][player2_action][0] - utility[0], 0)
    #player1_regret[1] += max(utilities[1][player2_action][0] - utility[0], 0)
    #player2_regret[0] += max(utilities[player1_action][0][1] - utility[1], 0)
    #player2_regret[1] += max(utilities[player1_action][1][1] - utility[1], 0)
    ################################################################################
    
    player1_regret[0] += utilities[0][player2_action][0] - utility[0]
    player1_regret[1] += utilities[1][player2_action][0] - utility[0]
    player2_regret[0] += utilities[player1_action][0][1] - utility[1]
    player2_regret[1] += utilities[player1_action][1][1] - utility[1]

# %%
joint2.plans

# %%
player1_regret_sum

# %%
u = [0, 0]
plans = ["a0.0a1.0", "a0.0a1.1", "a0.1a1.0", "a0.1a1.1"]
actions = [(0, 0), (0, 1), (1, 0), (1, 1)]
for i in range(len(plans)):
    plan = plans[i]
    u[0] += (joint2.plans[plan] / joint2.frequencyCount) * utilities[actions[i][0]][actions[i][1]][0]
    u[1] += (joint2.plans[plan] / joint2.frequencyCount) * utilities[actions[i][0]][actions[i][1]][1]
    print(plan, joint2.plans[plan] / joint2.frequencyCount)
u

# %%
for a1 in range(2):
    u_alt = 0
    for i in range(len(plans)):
        plan = plans[i]
        u_alt += (joint2.plans[plan] / joint2.frequencyCount) * utilities[a1][actions[i][1]][0]
    print(str(u[0]) + " >= " + str(u_alt))
    print("a1 = " + str(a1) + "\tepsilon = " + str(u[0] - u_alt))
    
for a2 in range(2):
    u_alt = 0
    for i in range(len(plans)):
        plan = plans[i]
        u_alt += (joint2.plans[plan] / joint2.frequencyCount) * utilities[actions[i][0]][a2][1]
    print(str(u[1]) + " >= " + str(u_alt))
    print("a1 = " + str(a2) + "\tepsilon = " + str(u[1] - u_alt))

# %%
t.checkEquilibrium(joint2)

# %% [markdown]
# z := <br>
# a0 b0   0.168353 <br>
# a0 b1   0.455176 <br>
# a1 b0   0.101647 <br>
# a1 b1   0.274824 <br>

# %%
res = SolveWithSampleCFR(t, 2, 10000)

# %%
res

# %%
t.checkEquilibrium(res['joint'])

# %% [markdown]
# ---
# # Timing tests (old)

# %%
# %time randomTreeTest(12, 2, 2, 0.5, 100)

# %%
# %time randomTreeTest(12, 2, 2, 1, 100)

# %%
# %time randomTreeTest(13, 2, 2, 0.5, 100)

# %%
# %time randomTreeTest(14, 2, 2, 0.5, 100)

# %% [markdown]
# ---

# %%
depth = 8
branching_factor = 2
players = 2
p = 0.5
iterations = 10000

check_equilibrium = True

start_time = time.time()
bt = randomTree(depth, branching_factor, p, players)
print("Building random tree in " + str(time.time() - start_time) + " seconds.")
start_time = time.time()
t = CFRTree(bt)
print("Building CFR tree in " + str(time.time() - start_time) + " seconds.")
start_time = time.time()
res = SolveWithSampleCFR(t, players, iterations)
print("Solving with CFR (" + str(iterations) + " iterations) in " + str(time.time() - start_time) + " seconds.")
print("Each iteration (approximately) " + str((time.time() - start_time) / iterations) + " seconds long.")

if(check_equilibrium):
    start_time = time.time()
    epsilon = t.checkEquilibrium(res['joint'])
    print("Checking equilibrium in " + str(time.time() - start_time) + " seconds.")
    mod_epsilon = math.sqrt(reduce(lambda acc, e: acc + (e * e if(e < 0) else 0), epsilon, 0))
    print("Equilibrium is an epsilon-NFCCE with |epsilon| = " + str(mod_epsilon))

# %% [markdown]
# Depth = n  ----->  approx 2^n milliseconds for each 100 iterations

# %%
plansLengths = list(map(lambda p: len(p.split('a'))-1, res['joint'].plans.keys()))
avgPlanLength = sum(plansLengths) / len(plansLengths)

print(str(len(res['joint'].plans)) + " plans each in average " + str(avgPlanLength) + " actions long")
print("|I| = " + str(len(t.information_sets)))

# %%
res['joint'].maxPlanCount

# %%
len(list(filter(lambda el: el[1] < 2, res['joint'].plans.items())))

# %%
list(filter(lambda el: el[1] > 3, res['joint'].plans.items()))

# %%
max(res['joint'].plans.items(), key = lambda el: el[1])

# %%
res = SolveWithSampleCFR(t, players, iterations * 10)
epsilon = t.checkEquilibrium(res['joint'])
mod_epsilon = math.sqrt(reduce(lambda acc, e: acc + (e * e if(e < 0) else 0), epsilon, 0))
epsilon

# %%
count = 0
for iset in t.information_sets.values():
    if(max(iset.current_strategy) >= 0.99):
        print(iset)
        print(iset.current_strategy)
        count += 1
count
