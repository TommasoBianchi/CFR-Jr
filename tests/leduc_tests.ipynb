# %%
cd ..
# Out:
# /home/tommy/Scrivania/Polimi/Honours Programme/SCFR

# %%
from games.leduc import build_leduc_tree
from data_structures.cfr_trees import CFRTree
from cfr_code.sample_cfr import SolveWithSampleCFR
from utilities.graphs import graphs_from_cfr_results

# %%
leduc_tree = build_leduc_tree(2, 2, 2, [2, 4])

# %%
cfr_tree = CFRTree(leduc_tree)

# %%
# %time res = SolveWithSampleCFR(cfr_tree, iterations = 100000, bootstrap_iterations = 10000, \
                               show_perc = True, perc = 5, checkEveryIteration = 1000)
# Out:
# 5.0%
# 10.0%
# 15.0%
# 20.0%
# 25.0%
# 30.0%
# 35.0%
# 40.0%
# 45.0%
# 50.0%
# 55.0%
# 60.0%
# 65.0%
# 70.0%
# 75.0%
# 80.0%
# 85.0%
# 90.0%
# 95.0%
# 100.0%
# CPU times: user 1min 47s, sys: 24 ms, total: 1min 47s
# Wall time: 1min 47s

# %%
graphs_from_cfr_results(res)

# %%
cfr_tree2 = CFRTree(leduc_tree)
# %time res2 = SolveWithSampleCFR(cfr_tree2, iterations = 100000, bootstrap_iterations = 10000, \
                               show_perc = True, perc = 5, checkEveryIteration = 1000, bound_joint_size = False)
# Out:
# 5.0%
# 10.0%
# 15.0%
# 20.0%
# 25.0%
# 30.0%
# 35.0%
# 40.0%
# 45.0%
# 50.0%
# 55.0%
# 60.0%
# 65.0%
# 70.0%
# 75.0%
# 80.0%
# 85.0%
# 90.0%
# 95.0%
# 100.0%
# CPU times: user 10min 11s, sys: 152 ms, total: 10min 11s
# Wall time: 10min 11s

# %%
graphs_from_cfr_results(res2)
