# %%
cd ..
# Out:
# /home/tommy/Scrivania/Polimi/Honours Programme/SCFR

# %%
from games.leduc import build_leduc_tree
from data_structures.cfr_trees import CFRTree
from cfr_code.sample_cfr import SolveWithSampleCFR
from utilities.graphs import graphs_from_cfr_results, epsilon_graph

# %%
leduc_tree = build_leduc_tree(2, 2, 2, [2, 4])

# %%
cfr_tree = CFRTree(leduc_tree)

# %%
# %time res = SolveWithSampleCFR(cfr_tree, iterations = 10000, bootstrap_iterations = 1000, \
                               show_perc = True, perc = 10, checkEveryIteration = 100)
# Out:
# 10.0%
# 20.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 100.0%
# CPU times: user 8.89 s, sys: 4 ms, total: 8.89 s
# Wall time: 8.89 s

# %%
epsilon_graph(res)

# %%
cfr_tree2 = CFRTree(leduc_tree)
# %time res2 = SolveWithSampleCFR(cfr_tree2, iterations = 10000, bootstrap_iterations = 10000, \
                               show_perc = True, perc = 10, checkEveryIteration = 1000, bound_joint_size = False)
# Out:
# 10.0%
# 20.0%
# 30.0%
# 40.0%
# 50.0%
# 60.0%
# 70.0%
# 80.0%
# 90.0%
# 100.0%
# CPU times: user 14min 11s, sys: 1.5 s, total: 14min 12s
# Wall time: 14min 13s

# %%
graphs_from_cfr_results(res2)
